# %% [markdown]
# # Challenge 04 Tuned: Random forest

# %% [markdown]
# ## Objective
#
# This notebook is intentionally designed for a heavier search budget.
# The goal is to push the selected model beyond the previous local baseline using a two-stage search:
#
# 1. A broad coarse search across the most promising region.
# 2. A fine search built automatically around the best coarse configuration.
#
# These notebooks are expected to take substantially longer than the `Ready` versions.
# They are prepared for manual execution and are not guaranteed to exceed 0.90, but they are explicitly configured to chase that target as hard as this model family reasonably allows.

# %% [markdown]
# ## 0. Load libraries

# %%
from pathlib import Path
import json
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
from sklearn.decomposition import PCA
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid", context="talk")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["axes.titlesize"] = 14
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["savefig.bbox"] = "tight"

RANDOM_STATE = 301655
OUTER_TEST_SIZE = 0.20
SEARCH_CV = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# %% [markdown]
# ## 1. Configure the model family and the coarse search space

# %%
from sklearn.ensemble import RandomForestClassifier

MODEL_NAME = "Random forest"
NOTEBOOK_SLUG = "challenge_04_random_forest_tuned"
BASELINE_REFERENCE = {
    "previous_local_best_validation_accuracy": 0.7405,
    "goal": "Test whether larger forests and broader split settings can materially close the gap with KNN."
}

COARSE_PIPELINE = RandomForestClassifier(
    random_state=RANDOM_STATE,
    n_jobs=1,
)

COARSE_GRID = {
    "n_estimators": [100, 200, 400, 800],
    "max_depth": [None, 24, 36],
    "min_samples_leaf": [1, 2, 3, 5],
    "min_samples_split": [2, 5, 10],
    "max_features": [0.2, 0.3, 0.5, "sqrt"],
    "criterion": ["gini", "entropy"],
}

# %% [markdown]
# ## 2. Load the challenge data

# %%
BASE_DIR = Path.cwd()
TRAIN_PATH = BASE_DIR / "data" / "training.csv"
TEST_PATH = BASE_DIR / "data" / "test.csv"
SAMPLE_PATH = BASE_DIR / "data" / "sample.csv"

train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
sample_df = pd.read_csv(SAMPLE_PATH)

X = train_df.drop(columns=["id", "class"])
y = train_df["class"]
X_test_kaggle = test_df.drop(columns=["id"])

output_dir = BASE_DIR / "output" / NOTEBOOK_SLUG
output_dir.mkdir(parents=True, exist_ok=True)

submission_dir = BASE_DIR / "submissions"
submission_dir.mkdir(parents=True, exist_ok=True)

def save_current_figure(filename: str) -> Path:
    path = output_dir / filename
    plt.tight_layout()
    plt.savefig(path, dpi=200)
    return path

def evaluate_predictions(y_true: pd.Series, y_pred: np.ndarray) -> dict:
    cm = confusion_matrix(y_true, y_pred)
    return {
        "accuracy": float(accuracy_score(y_true, y_pred)),
        "confusion_matrix": cm.tolist(),
    }

# %% [markdown]
# ## 3. Quick audit of the dataset

# %%
print("Training shape:", train_df.shape)
print("Test shape:", test_df.shape)
print("Sample submission shape:", sample_df.shape)
print("\nClass balance:")
display(train_df["class"].value_counts().sort_index())

print("\nMissing values in training:", int(train_df.isna().sum().sum()))
print("Missing values in test:", int(test_df.isna().sum().sum()))
print("Duplicated training rows:", int(train_df.duplicated().sum()))
# Out:
# Training shape: (10000, 202)
# Test shape: (3000, 201)
# Sample submission shape: (3000, 2)
#
# Class balance:
# class
# 0    5000
# 1    5000
# Name: count, dtype: int64
# Missing values in training: 0
# Missing values in test: 0
# Duplicated training rows: 0

# %% [markdown]
# ## 4. PCA diagnostic

# %%
scaler_for_pca = StandardScaler()
X_scaled_full = scaler_for_pca.fit_transform(X)

pca_full = PCA(random_state=RANDOM_STATE)
pca_full.fit(X_scaled_full)
cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)

plt.figure(figsize=(10, 5))
plt.plot(np.arange(1, len(cumulative_variance) + 1), cumulative_variance, marker="o")
plt.axhline(0.80, color="tomato", linestyle="--", label="80% variance")
plt.axhline(0.90, color="darkgreen", linestyle="--", label="90% variance")
plt.title("Cumulative explained variance from PCA")
plt.xlabel("Number of principal components")
plt.ylabel("Cumulative explained variance")
plt.legend()
pca_variance_path = save_current_figure("pca_cumulative_variance.png")
plt.show()

print(f"Saved figure: {pca_variance_path}")
print("Components for 80% variance:", int(np.argmax(cumulative_variance >= 0.80) + 1))
print("Components for 90% variance:", int(np.argmax(cumulative_variance >= 0.90) + 1))
# Out:
# Saved figure: /Users/williamfrankmonroymamani/Documents/mem/stadistics/mem-estadistics/challenge/output/challenge_04_random_forest_tuned/pca_cumulative_variance.png
# Components for 80% variance: 20
# Components for 90% variance: 44

# %% [markdown]
# ## 5. Create training and validation splits

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X,
    y,
    test_size=OUTER_TEST_SIZE,
    stratify=y,
    random_state=RANDOM_STATE,
)

print("Training split:", X_train.shape, y_train.shape)
print("Validation split:", X_valid.shape, y_valid.shape)
# Out:
# Training split: (8000, 200) (8000,)
# Validation split: (2000, 200) (2000,)

# %% [markdown]
# ## 6. Coarse search

# %%
coarse_search = GridSearchCV(
    estimator=COARSE_PIPELINE,
    param_grid=COARSE_GRID,
    scoring="accuracy",
    cv=SEARCH_CV,
    n_jobs=1,
    refit=True,
    verbose=2,
)

coarse_search.fit(X_train, y_train)

print("Coarse best CV accuracy:", round(coarse_search.best_score_, 4))
print("Coarse best params:")
print(coarse_search.best_params_)

coarse_results = (
    pd.DataFrame(coarse_search.cv_results_)
    .sort_values("rank_test_score")
    .reset_index(drop=True)
)
display(coarse_results.loc[:, ["rank_test_score", "mean_test_score", "std_test_score", "params"]].head(10))
coarse_results.to_csv(output_dir / "coarse_cv_results.csv", index=False)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  16.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  16.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  16.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  16.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  16.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  31.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  35.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  33.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  35.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  32.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 3.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  25.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  25.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  25.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  25.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  25.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  50.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  50.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  52.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  51.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  51.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  26.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  25.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  25.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  25.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  24.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  50.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  49.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  50.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  50.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  50.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  30.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  59.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  39.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  45.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  45.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  46.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  46.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 3.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 2.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 3.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  31.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  34.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  31.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  33.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  31.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time= 2.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  18.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  16.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  16.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  16.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  31.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  32.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  31.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  31.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=  31.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time= 2.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time= 2.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time= 2.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=  22.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=  22.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  43.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  43.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  43.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  44.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  43.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time= 1.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time= 1.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time= 2.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time= 2.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  15.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  15.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  14.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=  14.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  28.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  28.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  28.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  28.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  32.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time= 2.7min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time= 2.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time= 2.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  38.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  38.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  37.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  38.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  37.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time= 1.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time= 1.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time= 2.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  18.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  19.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  19.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  19.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  37.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  37.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  38.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  39.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  38.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 1.3min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time= 2.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time= 2.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=  18.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=  19.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=  19.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  37.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  37.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  58.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time= 3.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  37.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time= 1.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time= 1.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  56.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  54.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  58.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.2, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.7s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  45.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  49.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 4.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 3.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 4.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 4.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time= 4.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  31.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  31.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  31.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  31.3s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  31.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 4.2min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 4.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=5, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  23.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  45.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  45.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  45.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  45.6s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  45.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time= 3.0min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  21.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  22.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  21.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  44.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  44.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=2, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  21.8s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  43.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  44.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  43.9s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  44.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  44.0s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time= 1.5min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 6.1min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 7.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 7.4min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=5, n_estimators=800; total time= 7.6min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  54.4s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  55.2s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  54.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  55.1s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  55.5s
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.9min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=0.3, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.9min
# ...
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  19.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  19.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=  19.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time=  56.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time=  54.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time=  52.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time=  53.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=800; total time=  52.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   7.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  12.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  13.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  13.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  13.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200; total time=  13.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time=  26.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time=  26.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time=  26.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time=  26.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=400; total time=  26.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time=  52.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time=  54.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time=  53.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time=  53.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=800; total time=  52.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   7.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   6.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  13.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  12.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  13.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  13.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=  12.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  26.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  26.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  26.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  26.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  26.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time=  52.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time=  51.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time=  52.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time=  53.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=800; total time=  51.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  12.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  13.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  12.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  12.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  12.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=  25.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=  25.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=  25.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=  25.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=400; total time=  25.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  51.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  50.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  50.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  51.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  49.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  12.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  12.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  12.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  12.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=  12.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  25.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  25.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  25.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  26.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=  25.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  51.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  51.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  51.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  51.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=800; total time=  50.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  12.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  12.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  12.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  12.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  13.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  25.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  26.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  25.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  25.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  25.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  51.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  51.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  51.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  51.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  52.0s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  19.3s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  19.4s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  19.8s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  19.7s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.5s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  38.4s
# [CV] END criterion=gini, max_depth=24, max_features=0.2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  40.1s

# %% [markdown]
# ## 7. Build the fine search space around the best coarse configuration

# %%
best_n_estimators = coarse_search.best_params_["n_estimators"]
best_max_depth = coarse_search.best_params_["max_depth"]
best_min_samples_leaf = coarse_search.best_params_["min_samples_leaf"]
best_min_samples_split = coarse_search.best_params_["min_samples_split"]
best_max_features = coarse_search.best_params_["max_features"]
best_criterion = coarse_search.best_params_["criterion"]

candidate_n_estimators = sorted(
    {
        value
        for value in [
            max(100, best_n_estimators // 2),
            best_n_estimators,
            best_n_estimators + 200,
            best_n_estimators + 400,
        ]
        if value <= 1200
    }
)

depth_candidates = {best_max_depth, None}
if isinstance(best_max_depth, int):
    depth_candidates.update({max(8, best_max_depth - 8), best_max_depth + 8})

feature_candidates = {best_max_features, "sqrt"}
if isinstance(best_max_features, float):
    feature_candidates.update(
        {
            max(0.1, round(best_max_features - 0.1, 2)),
            round(best_max_features, 2),
            min(0.8, round(best_max_features + 0.1, 2)),
        }
    )
else:
    feature_candidates.update({0.3, 0.5})

FINE_PIPELINE = COARSE_PIPELINE
FINE_GRID = {
    "n_estimators": candidate_n_estimators,
    "max_depth": list(depth_candidates),
    "min_samples_leaf": sorted({1, best_min_samples_leaf, best_min_samples_leaf + 1, best_min_samples_leaf + 2}),
    "min_samples_split": sorted({2, best_min_samples_split, best_min_samples_split + 5}),
    "max_features": list(feature_candidates),
    "criterion": sorted({best_criterion, "gini", "entropy", "log_loss"}),
}

print("Fine grid:")
print(FINE_GRID)

# %% [markdown]
# ## 8. Fine search

# %%
fine_search = GridSearchCV(
    estimator=FINE_PIPELINE,
    param_grid=FINE_GRID,
    scoring="accuracy",
    cv=SEARCH_CV,
    n_jobs=1,
    refit=True,
    verbose=2,
)

fine_search.fit(X_train, y_train)

print("Fine best CV accuracy:", round(fine_search.best_score_, 4))
print("Fine best params:")
print(fine_search.best_params_)

fine_results = (
    pd.DataFrame(fine_search.cv_results_)
    .sort_values("rank_test_score")
    .reset_index(drop=True)
)
display(fine_results.loc[:, ["rank_test_score", "mean_test_score", "std_test_score", "params"]].head(10))
fine_results.to_csv(output_dir / "fine_cv_results.csv", index=False)

search = fine_search

# %% [markdown]
# ## 9. Visualize the fine-search surface

# %%
rf_results = fine_results.copy()
rf_results["n_estimators"] = rf_results["param_n_estimators"].astype(int)
rf_results["max_depth"] = rf_results["param_max_depth"].astype(str)
rf_results["min_samples_leaf"] = rf_results["param_min_samples_leaf"].astype(int)
rf_results["max_features"] = rf_results["param_max_features"].astype(str)

best_depth = rf_results.iloc[0]["max_depth"]
best_leaf = rf_results.iloc[0]["min_samples_leaf"]

heatmap_data = (
    rf_results[
        (rf_results["max_depth"] == best_depth)
        & (rf_results["min_samples_leaf"] == best_leaf)
    ]
    .pivot_table(
        index="max_features",
        columns="n_estimators",
        values="mean_test_score",
    )
)

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".3f", cmap="rocket_r")
plt.title(f"Random forest fine-search heatmap\nmax_depth={best_depth}, min_samples_leaf={best_leaf}")
plt.xlabel("Number of trees")
plt.ylabel("max_features")
heatmap_path = save_current_figure("rf_fine_heatmap.png")
plt.show()

print(f"Saved figure: {heatmap_path}")

importances = pd.Series(search.best_estimator_.feature_importances_, index=X.columns).sort_values(ascending=False).head(20)
plt.figure(figsize=(12, 8))
sns.barplot(x=importances.values, y=importances.index, palette="flare")
plt.title("Top random forest feature importances")
plt.xlabel("Importance")
plt.ylabel("Predictor")
importance_path = save_current_figure("rf_feature_importance.png")
plt.show()

print(f"Saved figure: {importance_path}")

# %% [markdown]
# ## 10. Evaluate the best tuned model on the holdout validation split

# %%
valid_predictions = search.predict(X_valid)
validation_report = evaluate_predictions(y_valid, valid_predictions)
validation_accuracy = validation_report["accuracy"]

print("Validation accuracy:", round(validation_accuracy, 4))
print("Confusion matrix:")
print(np.array(validation_report["confusion_matrix"]))

disp = ConfusionMatrixDisplay.from_predictions(
    y_valid,
    valid_predictions,
    display_labels=["Undamaged (0)", "Damaged (1)"],
    cmap="Blues",
    colorbar=False,
)
disp.ax_.set_title("Validation confusion matrix")
confusion_path = save_current_figure("validation_confusion_matrix.png")
plt.show()

print(f"Saved figure: {confusion_path}")

# %% [markdown]
# ## Interpretation
#
# Random forest is being pushed here with larger forests, wider feature-subsampling ranges, and looser tree-growth controls than the previous notebook.
# If it still stays well below KNN after this search, that is strong evidence that this family is not the best use of training time for this dataset.

# %% [markdown]
# ## 11. Refit on the full training set and generate the submission file

# %%
final_model = search.best_estimator_
final_model.fit(X, y)
test_predictions = final_model.predict(X_test_kaggle)

submission_df = pd.DataFrame(
    {
        "id": test_df["id"],
        "class": test_predictions.astype(int),
    }
)

submission_path = submission_dir / f"{NOTEBOOK_SLUG}_submission.csv"
submission_df.to_csv(submission_path, index=False)
submission_df.head()

print(f"Submission saved to: {submission_path}")

# %% [markdown]
# ## 12. Save the tuning summary

# %%
summary_payload = {
    "model_name": MODEL_NAME,
    "strategy": "coarse_to_fine_grid_search",
    "baseline_reference": BASELINE_REFERENCE,
    "coarse_best_cv_accuracy": float(coarse_search.best_score_),
    "coarse_best_params": coarse_search.best_params_,
    "fine_best_cv_accuracy": float(fine_search.best_score_),
    "fine_best_params": fine_search.best_params_,
    "validation_accuracy": validation_accuracy,
    "output_dir": str(output_dir),
    "submission_path": str(submission_path),
}

summary_path = output_dir / "summary.json"
summary_path.write_text(json.dumps(summary_payload, indent=2))

print("Summary saved to:", summary_path)
summary_payload
